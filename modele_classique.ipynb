# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

df = pd.read_csv('heart_clean.csv').iloc[:, 1:]

# %%
## Apply a model depending of the classifier
def app_model(classifier):
    
    X = df.drop(['malade'], axis = 1)
    y = df['malade']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

    classifier.fit(X_train, y_train)

    y_pred = classifier.predict(X_test)
    print("\nClassifier name : %s" % classifier)
    print("Accuracy : %s" % accuracy_score(y_test, y_pred))
    print("Confusion Matrix : \n", confusion_matrix(y_test, y_pred))
    print("Classification Report : \n", classification_report(y_test, y_pred))

# %% [markdown]
# ## Apprentissage supervisée

# %%
## apply SVC model
from sklearn.svm import SVC
classifier_scv = SVC(gamma = 'scale', kernel = 'linear')
app_model(classifier_scv)
# Out:
# Classifier name : SVC(kernel='linear')
# Accuracy : 0.7160886626365468
# Confusion Matrix :
#  [[3749 1042]
#  [1635 3003]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74      4791
#            1       0.74      0.65      0.69      4638
#
#     accuracy                           0.72      9429
#    macro avg       0.72      0.71      0.71      9429
# weighted avg       0.72      0.72      0.71      9429

# %%
## apply k-nearest-neighbors model
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
app_model(classifier_knn)
# Out:
# Classifier name : KNeighborsClassifier()
# Accuracy : 0.6698483402269594
# Confusion Matrix :
#  [[3315 1476]
#  [1637 3001]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68      4791
#            1       0.67      0.65      0.66      4638
#
#     accuracy                           0.67      9429
#    macro avg       0.67      0.67      0.67      9429
# weighted avg       0.67      0.67      0.67      9429

# %%
## apply k-nearest-neighbors model
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors = 25, metric = 'minkowski', p = 2)
app_model(classifier_knn)
# Out:
# Classifier name : KNeighborsClassifier(n_neighbors=25)
# Accuracy : 0.7137554353589989
# Confusion Matrix :
#  [[3720 1071]
#  [1628 3010]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.70      0.78      0.73      4791
#            1       0.74      0.65      0.69      4638
#
#     accuracy                           0.71      9429
#    macro avg       0.72      0.71      0.71      9429
# weighted avg       0.72      0.71      0.71      9429

# %%
## apply k-nearest-neighbors model
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors = 50, metric = 'minkowski', p = 2)
app_model(classifier_knn)
# Out:
# Classifier name : KNeighborsClassifier(n_neighbors=50)
# Accuracy : 0.7176794994166932
# Confusion Matrix :
#  [[3854  937]
#  [1725 2913]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74      4791
#            1       0.76      0.63      0.69      4638
#
#     accuracy                           0.72      9429
#    macro avg       0.72      0.72      0.71      9429
# weighted avg       0.72      0.72      0.72      9429

# %%
## apply k-nearest-neighbors model
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors = 100, metric = 'minkowski', p = 2)
app_model(classifier_knn)
# Out:
# Classifier name : KNeighborsClassifier(n_neighbors=100)
# Accuracy : 0.7154523279244883
# Confusion Matrix :
#  [[3891  900]
#  [1783 2855]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.69      0.81      0.74      4791
#            1       0.76      0.62      0.68      4638
#
#     accuracy                           0.72      9429
#    macro avg       0.72      0.71      0.71      9429
# weighted avg       0.72      0.72      0.71      9429

# %%
## apply decision tree model
from sklearn.tree import DecisionTreeClassifier
classifier_dtc = DecisionTreeClassifier(criterion = 'entropy', random_state = 0, max_depth=10)
app_model(classifier_dtc)
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(classifier_dtc, filled=True)
# Out:
# Classifier name : DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=0)
# Accuracy : 0.7231944002545339
# Confusion Matrix :
#  [[3859  932]
#  [1678 2960]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75      4791
#            1       0.76      0.64      0.69      4638
#
#     accuracy                           0.72      9429
#    macro avg       0.73      0.72      0.72      9429
# weighted avg       0.73      0.72      0.72      9429

# %%
classifier_dtc2 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0, max_depth=10, min_samples_leaf=100)
app_model(classifier_dtc2)
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(classifier_dtc2, filled=True)
# Out:
# Classifier name : DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=100,
#                        random_state=0)
# Accuracy : 0.7270124085268851
# Confusion Matrix :
#  [[3744 1047]
#  [1527 3111]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      4791
#            1       0.75      0.67      0.71      4638
#
#     accuracy                           0.73      9429
#    macro avg       0.73      0.73      0.73      9429
# weighted avg       0.73      0.73      0.73      9429

# %%
## apply logistic regression
from sklearn.linear_model import LogisticRegression
classifier_log = LogisticRegression(random_state = 0)
app_model(classifier_log)
plt.figure(figsize=(16,16))
#plt.bar(x = df.columns.values, height = np.append(classifierlog.intercept, classifierlog.coef[0]))
plt.bar(x = df.drop(['malade'], axis=1).columns.values, height = classifier_log.coef_[0])
plt.xticks(rotation= 80)
print("Intercept : %s" % classifier_log.intercept_)
# Out:
# Classifier name : LogisticRegression(random_state=0)
# Accuracy : 0.727966910594973
# Confusion Matrix :
#  [[3773 1018]
#  [1547 3091]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      4791
#            1       0.75      0.67      0.71      4638
#
#     accuracy                           0.73      9429
#    macro avg       0.73      0.73      0.73      9429
# weighted avg       0.73      0.73      0.73      9429
#
# Intercept : [0.34404168]

# %% [markdown]
# ## Apprentissage d'ensemble

# %%
## apply random forest model
from sklearn.ensemble import RandomForestClassifier
classifier_rfc = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
app_model(classifier_rfc)
# Out:
# Classifier name : RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)
# Accuracy : 0.6779085799130342
# Confusion Matrix :
#  [[3551 1240]
#  [1797 2841]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70      4791
#            1       0.70      0.61      0.65      4638
#
#     accuracy                           0.68      9429
#    macro avg       0.68      0.68      0.68      9429
# weighted avg       0.68      0.68      0.68      9429

# %%
## apply ada boost
from sklearn.ensemble import AdaBoostClassifier
classifier_abc = AdaBoostClassifier()
app_model(classifier_abc)
# Out:
# Classifier name : AdaBoostClassifier()
# Accuracy : 0.7260579064587973
# Confusion Matrix :
#  [[3764 1027]
#  [1556 3082]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.79      0.74      4791
#            1       0.75      0.66      0.70      4638
#
#     accuracy                           0.73      9429
#    macro avg       0.73      0.73      0.72      9429
# weighted avg       0.73      0.73      0.72      9429
